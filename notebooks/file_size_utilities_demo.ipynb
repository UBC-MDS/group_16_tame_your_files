# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path("..").resolve()
SRC_DIR = PROJECT_ROOT / "src"
sys.path.insert(0, str(SRC_DIR))

# %%
from pathlib import Path
from tame_your_files.file_size_utilities import (
    largest_files,
    files_to_free_space,
)

# %%
# Demonstrate finding the 5 largest files in a chosen directory
# This includes files in the root folder and all subfolders
demo_dir = Path.home() / "Desktop" / "mds" / "Projects"
largest = largest_files(demo_dir, n=5)

print(f"5 largest files in {demo_dir} (including all subdirectories):")
print("-" * 60)
for file_info in largest:
    size_mb = file_info.size_bytes / (1024 * 1024)
    print(f"{file_info.path} - {size_mb:.2f} MB ({file_info.size_bytes} bytes)")
# Out:
# Directory does not exist: /Desktop/mds/Projects

# %%
# Demonstrate finding which files would free a specified amount of space
# This includes files in the root folder and all subfolders
demo_dir = Path.home() / "Desktop" / "mds" / "Projects"
target_bytes = 10 * 1024 * 1024  # 10 MB
files_to_delete = files_to_free_space(demo_dir, target_bytes)

print(f"\nFiles that would free at least {target_bytes / (1024 * 1024):.2f} MB (including all subdirectories):")
print("-" * 60)
total_size = 0
for file_info in files_to_delete:
    size_mb = file_info.size_bytes / (1024 * 1024)
    total_size += file_info.size_bytes
    print(f"{file_info.path} - {size_mb:.2f} MB ({file_info.size_bytes} bytes)")

print(f"\nTotal size: {total_size / (1024 * 1024):.2f} MB ({total_size} bytes)")
# Out:
# Files that would free at least 10.00 MB (including all subdirectories):
# ------------------------------------------------------------
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.git/objects/pack/pack-a437003dfe55e004b4b5a93d463cf3623f9fb67a.pack - 0.02 MB (25135 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/DEVELOPMENT.md - 0.01 MB (10430 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.DS_Store - 0.01 MB (6148 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/pyproject.toml - 0.01 MB (6092 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/src/tame_your_files/__pycache__/file_size_utilities.cpython-312.pyc - 0.01 MB (5780 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/tests/test_file_size_utilities.py - 0.01 MB (5672 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/CODE_OF_CONDUCT.md - 0.01 MB (5293 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.git/hooks/pre-rebase.sample - 0.00 MB (4898 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.git/hooks/fsmonitor-watchman.sample - 0.00 MB (4726 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/docs/conf.py - 0.00 MB (4668 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/src/tame_your_files/file_size_utilities.py - 0.00 MB (4415 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.gitignore - 0.00 MB (4411 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/CONTRIBUTING.md - 0.00 MB (4060 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/notebooks/file_size_utilities_demo.ipynb - 0.00 MB (3879 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.git/hooks/update.sample - 0.00 MB (3650 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.git/hooks/push-to-checkout.sample - 0.00 MB (2783 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.github/workflows/release.yml - 0.00 MB (2745 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.git/index - 0.00 MB (2625 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.git/objects/pack/pack-a437003dfe55e004b4b5a93d463cf3623f9fb67a.idx - 0.00 MB (2360 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.github/ISSUE_TEMPLATE/01-bug-report.yml - 0.00 MB (1920 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.git/hooks/pre-commit.sample - 0.00 MB (1643 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.git/hooks/prepare-commit-msg.sample - 0.00 MB (1492 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.git/hooks/pre-push.sample - 0.00 MB (1374 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/src/tame_your_files/__init__.py - 0.00 MB (1373 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.github/workflows/test.yml - 0.00 MB (1328 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.git/objects/77/58daf105e6920093ff80f2217b07f66e5b1359 - 0.00 MB (1232 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.git/objects/70/6a249ecce2594d0a5c6d3c17daa1759680148e - 0.00 MB (1193 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.git/objects/11/15835d10236549c721eeeb3af86fb292e90788 - 0.00 MB (1181 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/README.md - 0.00 MB (1176 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/LICENSE - 0.00 MB (1117 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/docs/index.md - 0.00 MB (1006 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.git/hooks/commit-msg.sample - 0.00 MB (896 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.git/objects/f3/3a38f39b586039a52f89eeb7499e90bdc38e4e - 0.00 MB (828 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/src/tame_your_files/example.py - 0.00 MB (743 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.github/workflows/docs.yml - 0.00 MB (654 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/tests/unit/test_example.py - 0.00 MB (604 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.pytest_cache/v/cache/nodeids - 0.00 MB (562 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.git/config - 0.00 MB (553 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.git/hooks/pre-receive.sample - 0.00 MB (544 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.git/logs/HEAD - 0.00 MB (507 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.git/objects/ae/34f24c0235bd9e51f1c0adccaf9e07fb591b63 - 0.00 MB (485 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.git/hooks/applypatch-msg.sample - 0.00 MB (478 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.git/hooks/pre-applypatch.sample - 0.00 MB (424 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.git/hooks/pre-merge-commit.sample - 0.00 MB (416 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/src/tame_your_files/__pycache__/__init__.cpython-312.pyc - 0.00 MB (416 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/CHANGELOG.md - 0.00 MB (344 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.editorconfig - 0.00 MB (332 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.git/logs/refs/heads/ali - 0.00 MB (308 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.github/dependabot.yml - 0.00 MB (307 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.pytest_cache/README.md - 0.00 MB (302 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.git/packed-refs - 0.00 MB (291 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.git/info/exclude - 0.00 MB (240 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.github/ISSUE_TEMPLATE/config.yml - 0.00 MB (236 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.git/logs/refs/heads/main - 0.00 MB (191 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.git/logs/refs/remotes/origin/HEAD - 0.00 MB (191 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.pytest_cache/CACHEDIR.TAG - 0.00 MB (191 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.git/hooks/post-update.sample - 0.00 MB (189 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.git/objects/c4/0546ba278124a3e7c04a8bcb9c3e3f6f4d5994 - 0.00 MB (155 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.github/PULL_REQUEST_TEMPLATE.md - 0.00 MB (139 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.git/objects/c0/6cb4d34c8e09f92b56d9ca04c0482edc3836e0 - 0.00 MB (133 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.git/objects/64/806a332624db20260d40978c212978546f0c0f - 0.00 MB (102 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.git/objects/4d/fe43ec05343cb3076508bea4dd04f74d13f7d2 - 0.00 MB (75 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.git/description - 0.00 MB (73 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.git/objects/40/f4348f8551773826efca21531095918b2aeb05 - 0.00 MB (57 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.git/refs/heads/ali - 0.00 MB (41 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.git/refs/heads/main - 0.00 MB (41 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.pytest_cache/.gitignore - 0.00 MB (37 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.git/refs/remotes/origin/HEAD - 0.00 MB (30 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.git/HEAD - 0.00 MB (20 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.git/COMMIT_EDITMSG - 0.00 MB (12 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/.pytest_cache/v/cache/lastfailed - 0.00 MB (2 bytes)
# /Users/boloor/Desktop/mds/Projects/group_16_tame_your_files/docs/_static/.gitkeep - 0.00 MB (0 bytes)
#
# Total size: 0.13 MB (137954 bytes)
